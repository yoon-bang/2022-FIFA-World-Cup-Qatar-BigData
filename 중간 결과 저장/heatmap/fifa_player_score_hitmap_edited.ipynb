# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

import json
from IPython.core.display import display, HTML
import tempfile

from math import sqrt
import scipy.stats
import sys

import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

import plotly.graph_objects as go
import plotly.express as px

from sklearn import preprocessing
from sklearn.model_selection import train_test_split

from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
from sklearn.tree import plot_tree

import xgboost as xgb

from sklearn.metrics import r2_score, mean_absolute_error, mean_squared_error

# %%
df_results=pd.read_csv("/content/drive/MyDrive/Colab Notebooks/fifa/results.csv")
df_results.head(10)
# Out:
#          date home_team away_team  home_score  away_score tournament     city  \
# 0  1872-11-30  Scotland   England         0.0         0.0   Friendly  Glasgow
# 1  1873-03-08   England  Scotland         4.0         2.0   Friendly   London
# 2  1874-03-07  Scotland   England         2.0         1.0   Friendly  Glasgow
# 3  1875-03-06   England  Scotland         2.0         2.0   Friendly   London
# 4  1876-03-04  Scotland   England         3.0         0.0   Friendly  Glasgow
# 5  1876-03-25  Scotland     Wales         4.0         0.0   Friendly  Glasgow
# 6  1877-03-03   England  Scotland         1.0         3.0   Friendly   London
# 7  1877-03-05     Wales  Scotland         0.0         2.0   Friendly  Wrexham
# 8  1878-03-02  Scotland   England         7.0         2.0   Friendly  Glasgow
# 9  1878-03-23  Scotland     Wales         9.0         0.0   Friendly  Glasgow
#
#     country  neutral
# 0  Scotland    False
# 1   England    False
# 2  Scotland    False
# 3   England    False
# 4  Scotland    False
# 5  Scotland    False
# 6   England    False
# 7     Wales    False
# 8  Scotland    False
# 9  Scotland    False

# %%
df_shootouts=pd.read_csv("/content/drive/MyDrive/Colab Notebooks/fifa/shootouts.csv")

# %%
df_player15=pd.read_excel("/content/drive/MyDrive/Colab Notebooks/fifa/players/Career Mode player datasets - FIFA 15-22.xlsx", sheet_name=0)

# %%
df_results15=df_results.loc[df_results['date']>='2015-01-01'].loc[df_results['date']<'2016-01-01']
df_results15.head(10)
# Out:
#              date     home_team     away_team  home_score  away_score  \
# 36970  2015-01-04       Bahrain        Jordan         1.0         0.0
# 36971  2015-01-04          Iran          Iraq         1.0         0.0
# 36972  2015-01-04   South Korea  Saudi Arabia         2.0         0.0
# 36973  2015-01-04  South Africa        Zambia         1.0         0.0
# 36974  2015-01-05      China PR          Oman         4.0         1.0
# 36975  2015-01-07      Cameroon      DR Congo         1.0         1.0
# 36976  2015-01-09     Australia        Kuwait         4.0         1.0
# 36977  2015-01-09       Senegal         Gabon         1.0         0.0
# 36978  2015-01-10  Burkina Faso      Eswatini         5.0         1.0
# 36979  2015-01-10      Cameroon  South Africa         1.0         1.0
#
#           tournament          city       country  neutral
# 36970       Friendly      Ballarat     Australia     True
# 36971       Friendly    Wollongong     Australia     True
# 36972       Friendly    Parramatta     Australia     True
# 36973       Friendly  Johannesburg  South Africa    False
# 36974       Friendly       Penrith     Australia     True
# 36975       Friendly       Yaoundé      Cameroon    False
# 36976  AFC Asian Cup     Melbourne     Australia    False
# 36977       Friendly    Casablanca       Morocco     True
# 36978       Friendly     Nelspruit  South Africa     True
# 36979       Friendly    Libreville         Gabon     True

# %%
df_player15['rank_in_nation'] = df_player15.groupby("nationality_name")['value_eur'].rank(method="first", ascending=False)
df_player15['rank_in_nation'] = df_player15['rank_in_nation'].astype('Int64')
df_player15.sort_values('value_eur', ascending=False)
# Out:
#        sofifa_id                                         player_url  \
# 0         158023  https://sofifa.com/player/158023/lionel-messi/...
# 1          20801  https://sofifa.com/player/20801/c-ronaldo-dos-...
# 4         167495  https://sofifa.com/player/167495/manuel-neuer/...
# 2           9014  https://sofifa.com/player/9014/arjen-robben/15...
# 3          41236  https://sofifa.com/player/41236/zlatan-ibrahim...
# ...          ...                                                ...
# 15200     174441  https://sofifa.com/player/174441/rocus-lamare/...
# 15452     225444  https://sofifa.com/player/225444/joel-stevens/...
# 15534     216751  https://sofifa.com/player/216751/diego-bejaran...
# 15806     223760  https://sofifa.com/player/223760/amrinder-sing...
# 16152     201197  https://sofifa.com/player/201197/paul-tisdale/...
#
#               short_name                            long_name  \
# 0               L. Messi       Lionel Andrés Messi Cuccittini
# 1      Cristiano Ronaldo  Cristiano Ronaldo dos Santos Aveiro
# 4               M. Neuer                   Manuel Peter Neuer
# 2              A. Robben                         Arjen Robben
# 3         Z. Ibrahimović                   Zlatan Ibrahimović
# ...                  ...                                  ...
# 15200          R. Lamare                         Rocus Lamare
# 15452         J. Stevens                   Joel Craig Stevens
# 15534        D. Bejarano                Diego Bejarano Ibañez
# 15806           A. Singh                       Amrinder Singh
# 16152         P. Tisdale                         Paul Tisdale
#
#       player_positions  overall  potential    value_eur  wage_eur  age  ...  \
# 0                   CF       93         95  100500000.0  550000.0   27  ...
# 1               LW, LM       92         92   79000000.0  375000.0   29  ...
# 4                   GK       90         90   63500000.0  300000.0   28  ...
# 2           RM, LM, RW       90         90   54500000.0  275000.0   30  ...
# 3                   ST       90         90   52500000.0  275000.0   32  ...
# ...                ...      ...        ...          ...       ...  ...  ...
# 15200               CM       52         55          NaN       NaN   27  ...
# 15452          RM, CAM       52         56          NaN       NaN   19  ...
# 15534       RB, CB, RM       51         54          NaN       NaN   22  ...
# 15806               GK       50         54          NaN       NaN   21  ...
# 16152          CM, CAM       40         40          NaN    2000.0   41  ...
#
#          cb   rcb    rb    gk  \
# 0      45+3  45+3  54+3  15+3
# 1      52+3  52+3  57+3  16+3
# 4      38+3  38+3  36+3  87+3
# 2      46+3  46+3  55+3  14+3
# 3      55+3  55+3  56+3  17+3
# ...     ...   ...   ...   ...
# 15200    52    52    53    13
# 15452    35    35    37    10
# 15534    52    52    51    14
# 15806    31    31    28    50
# 16152    33    33    34    10
#
#                                          player_face_url  \
# 0      https://cdn.sofifa.net/players/158/023/15_120.png
# 1      https://cdn.sofifa.net/players/020/801/15_120.png
# 4      https://cdn.sofifa.net/players/167/495/15_120.png
# 2      https://cdn.sofifa.net/players/009/014/15_120.png
# 3      https://cdn.sofifa.net/players/041/236/15_120.png
# ...                                                  ...
# 15200  https://cdn.sofifa.net/players/174/441/15_120.png
# 15452  https://cdn.sofifa.net/players/225/444/15_120.png
# 15534  https://cdn.sofifa.net/players/216/751/15_120.png
# 15806  https://cdn.sofifa.net/players/223/760/15_120.png
# 16152  https://cdn.sofifa.net/players/201/197/15_120.png
#
#                                  club_logo_url  \
# 0      https://cdn.sofifa.net/teams/241/60.png
# 1      https://cdn.sofifa.net/teams/243/60.png
# 4       https://cdn.sofifa.net/teams/21/60.png
# 2       https://cdn.sofifa.net/teams/21/60.png
# 3       https://cdn.sofifa.net/teams/73/60.png
# ...                                        ...
# 15200                                      NaN
# 15452                                      NaN
# 15534                                      NaN
# 15806                                      NaN
# 16152  https://cdn.sofifa.net/teams/143/60.png
#
#                                  club_flag_url  \
# 0          https://cdn.sofifa.net/flags/es.png
# 1          https://cdn.sofifa.net/flags/es.png
# 4          https://cdn.sofifa.net/flags/de.png
# 2          https://cdn.sofifa.net/flags/de.png
# 3          https://cdn.sofifa.net/flags/fr.png
# ...                                        ...
# 15200                                      NaN
# 15452                                      NaN
# 15534                                      NaN
# 15806                                      NaN
# 16152  https://cdn.sofifa.net/flags/gb-eng.png
#
#                                   nation_logo_url  \
# 0        https://cdn.sofifa.net/teams/1369/60.png
# 1        https://cdn.sofifa.net/teams/1354/60.png
# 4        https://cdn.sofifa.net/teams/1337/60.png
# 2      https://cdn.sofifa.net/teams/105035/60.png
# 3        https://cdn.sofifa.net/teams/1363/60.png
# ...                                           ...
# 15200  https://cdn.sofifa.net/teams/111466/60.png
# 15452  https://cdn.sofifa.net/teams/111473/60.png
# 15534  https://cdn.sofifa.net/teams/111451/60.png
# 15806  https://cdn.sofifa.net/teams/111466/60.png
# 16152                                         NaN
#
#                            nation_flag_url rank_in_nation
# 0      https://cdn.sofifa.net/flags/ar.png              1
# 1      https://cdn.sofifa.net/flags/pt.png              1
# 4      https://cdn.sofifa.net/flags/de.png              1
# 2      https://cdn.sofifa.net/flags/nl.png              1
# 3      https://cdn.sofifa.net/flags/se.png              1
# ...                                    ...            ...
# 15200  https://cdn.sofifa.net/flags/in.png           <NA>
# 15452  https://cdn.sofifa.net/flags/nz.png           <NA>
# 15534  https://cdn.sofifa.net/flags/bo.png           <NA>
# 15806  https://cdn.sofifa.net/flags/in.png           <NA>
# 16152  https://cdn.sofifa.net/flags/mt.png           <NA>
#
# [16155 rows x 111 columns]

# %%
df_player15_wage = df_player15
df_player15_wage['rank_in_nation'] = df_player15_wage.groupby("nationality_name")['wage_eur'].rank(method="first", ascending=False)
df_player15_wage['rank_in_nation'] = df_player15_wage['rank_in_nation'].astype('Int64')
df_player15_wage.sort_values('wage_eur', ascending=False)
# Out:
#        sofifa_id                                         player_url  \
# 0         158023  https://sofifa.com/player/158023/lionel-messi/...
# 1          20801  https://sofifa.com/player/20801/c-ronaldo-dos-...
# 4         167495  https://sofifa.com/player/167495/manuel-neuer/...
# 6         176580  https://sofifa.com/player/176580/luis-suarez/1...
# 2           9014  https://sofifa.com/player/9014/arjen-robben/15...
# ...          ...                                                ...
# 15073     220542  https://sofifa.com/player/220542/romel-quinone...
# 15200     174441  https://sofifa.com/player/174441/rocus-lamare/...
# 15452     225444  https://sofifa.com/player/225444/joel-stevens/...
# 15534     216751  https://sofifa.com/player/216751/diego-bejaran...
# 15806     223760  https://sofifa.com/player/223760/amrinder-sing...
#
#               short_name                            long_name  \
# 0               L. Messi       Lionel Andrés Messi Cuccittini
# 1      Cristiano Ronaldo  Cristiano Ronaldo dos Santos Aveiro
# 4               M. Neuer                   Manuel Peter Neuer
# 6              L. Suárez             Luis Alberto Suárez Díaz
# 2              A. Robben                         Arjen Robben
# ...                  ...                                  ...
# 15073        R. Quiñonez         Romel Javier Quiñónez Suárez
# 15200          R. Lamare                         Rocus Lamare
# 15452         J. Stevens                   Joel Craig Stevens
# 15534        D. Bejarano                Diego Bejarano Ibañez
# 15806           A. Singh                       Amrinder Singh
#
#       player_positions  overall  potential    value_eur  wage_eur  age  ...  \
# 0                   CF       93         95  100500000.0  550000.0   27  ...
# 1               LW, LM       92         92   79000000.0  375000.0   29  ...
# 4                   GK       90         90   63500000.0  300000.0   28  ...
# 6               ST, CF       89         91   49500000.0  300000.0   27  ...
# 2           RM, LM, RW       90         90   54500000.0  275000.0   30  ...
# ...                ...      ...        ...          ...       ...  ...  ...
# 15073               GK       53         61          NaN       NaN   22  ...
# 15200               CM       52         55          NaN       NaN   27  ...
# 15452          RM, CAM       52         56          NaN       NaN   19  ...
# 15534       RB, CB, RM       51         54          NaN       NaN   22  ...
# 15806               GK       50         54          NaN       NaN   21  ...
#
#          cb   rcb    rb    gk  \
# 0      45+3  45+3  54+3  15+3
# 1      52+3  52+3  57+3  16+3
# 4      38+3  38+3  36+3  87+3
# 6      57+3  57+3  62+3  34+3
# 2      46+3  46+3  55+3  14+3
# ...     ...   ...   ...   ...
# 15073    30    30    28    53
# 15200    52    52    53    13
# 15452    35    35    37    10
# 15534    52    52    51    14
# 15806    31    31    28    50
#
#                                          player_face_url  \
# 0      https://cdn.sofifa.net/players/158/023/15_120.png
# 1      https://cdn.sofifa.net/players/020/801/15_120.png
# 4      https://cdn.sofifa.net/players/167/495/15_120.png
# 6      https://cdn.sofifa.net/players/176/580/15_120.png
# 2      https://cdn.sofifa.net/players/009/014/15_120.png
# ...                                                  ...
# 15073  https://cdn.sofifa.net/players/220/542/15_120.png
# 15200  https://cdn.sofifa.net/players/174/441/15_120.png
# 15452  https://cdn.sofifa.net/players/225/444/15_120.png
# 15534  https://cdn.sofifa.net/players/216/751/15_120.png
# 15806  https://cdn.sofifa.net/players/223/760/15_120.png
#
#                                  club_logo_url  \
# 0      https://cdn.sofifa.net/teams/241/60.png
# 1      https://cdn.sofifa.net/teams/243/60.png
# 4       https://cdn.sofifa.net/teams/21/60.png
# 6      https://cdn.sofifa.net/teams/241/60.png
# 2       https://cdn.sofifa.net/teams/21/60.png
# ...                                        ...
# 15073                                      NaN
# 15200                                      NaN
# 15452                                      NaN
# 15534                                      NaN
# 15806                                      NaN
#
#                              club_flag_url  \
# 0      https://cdn.sofifa.net/flags/es.png
# 1      https://cdn.sofifa.net/flags/es.png
# 4      https://cdn.sofifa.net/flags/de.png
# 6      https://cdn.sofifa.net/flags/es.png
# 2      https://cdn.sofifa.net/flags/de.png
# ...                                    ...
# 15073                                  NaN
# 15200                                  NaN
# 15452                                  NaN
# 15534                                  NaN
# 15806                                  NaN
#
#                                   nation_logo_url  \
# 0        https://cdn.sofifa.net/teams/1369/60.png
# 1        https://cdn.sofifa.net/teams/1354/60.png
# 4        https://cdn.sofifa.net/teams/1337/60.png
# 6                                             NaN
# 2      https://cdn.sofifa.net/teams/105035/60.png
# ...                                           ...
# 15073  https://cdn.sofifa.net/teams/111451/60.png
# 15200  https://cdn.sofifa.net/teams/111466/60.png
# 15452  https://cdn.sofifa.net/teams/111473/60.png
# 15534  https://cdn.sofifa.net/teams/111451/60.png
# 15806  https://cdn.sofifa.net/teams/111466/60.png
#
#                            nation_flag_url rank_in_nation
# 0      https://cdn.sofifa.net/flags/ar.png              1
# 1      https://cdn.sofifa.net/flags/pt.png              1
# 4      https://cdn.sofifa.net/flags/de.png              1
# 6      https://cdn.sofifa.net/flags/uy.png              1
# 2      https://cdn.sofifa.net/flags/nl.png              1
# ...                                    ...            ...
# 15073  https://cdn.sofifa.net/flags/bo.png           <NA>
# 15200  https://cdn.sofifa.net/flags/in.png           <NA>
# 15452  https://cdn.sofifa.net/flags/nz.png           <NA>
# 15534  https://cdn.sofifa.net/flags/bo.png           <NA>
# 15806  https://cdn.sofifa.net/flags/in.png           <NA>
#
# [16155 rows x 111 columns]

# %%
df_player15_wage = pd.DataFrame(df_player15_wage, columns=['short_name','nationality_name','nationality_id', 'wage_eur', 'rank_in_nation'])
df_player15_wage.head()
# Out:
#           short_name nationality_name  nationality_id  wage_eur  \
# 0           L. Messi        Argentina              52  550000.0
# 1  Cristiano Ronaldo         Portugal              38  375000.0
# 2          A. Robben      Netherlands              34  275000.0
# 3     Z. Ibrahimović           Sweden              46  275000.0
# 4           M. Neuer          Germany              21  300000.0
#
#    rank_in_nation
# 0               1
# 1               1
# 2               1
# 3               1
# 4               1

# %%
df_player15_selected = pd.DataFrame(df_player15, columns=['short_name','nationality_name','nationality_id', 'value_eur', 'rank_in_nation'])
df_player15_selected.head()
# rank_in_nation : 각 국가팀에서 이 선수가 몇번째로 돈 잘버는지 순위
# Out:
#           short_name nationality_name  nationality_id    value_eur  \
# 0           L. Messi        Argentina              52  100500000.0
# 1  Cristiano Ronaldo         Portugal              38   79000000.0
# 2          A. Robben      Netherlands              34   54500000.0
# 3     Z. Ibrahimović           Sweden              46   52500000.0
# 4           M. Neuer          Germany              21   63500000.0
#
#    rank_in_nation
# 0               1
# 1               1
# 2               1
# 3               1
# 4               1

# %%
# 'sofifa_id','short_name','long_name','vallue_eur','wage_eur','age','dob','nationality_id','nationality_name','nation_team_id','nation_position','nation_jersey_number','preferred_foot','weak_foot','skill_moves','international_reputation','pace'

df_player15_edited = pd.DataFrame(df_player15_selected, columns=['nationality_name', 'player1_value_eur']) # 'player1_wage_eur'

for i in range(2,4):
    col1 = 'player' + str(i) + '_value_eur'
   # col2 = 'player' + str(i) + '_wage_eur'
    df_player15_edited[col1] = np.nan
   # df_player15_edited[col2] = np.nan

#print(df_player15_edited)
df_player15_edited.head()
# Out:
#   nationality_name  player1_value_eur  player2_value_eur  player3_value_eur
# 0        Argentina                NaN                NaN                NaN
# 1         Portugal                NaN                NaN                NaN
# 2      Netherlands                NaN                NaN                NaN
# 3           Sweden                NaN                NaN                NaN
# 4          Germany                NaN                NaN                NaN

# %%
df_player15.iloc[0]['sofifa_id']
# Out:
# 158023

# %%
nationality_ids = df_player15_selected['nationality_id'].tolist()

# %%
len(nationality_ids)
# Out:
# 16155

# %%
df_player15_edited.head()
# Out:
#   nationality_name  player1_value_eur  player2_value_eur  player3_value_eur
# 0        Argentina                NaN                NaN                NaN
# 1         Portugal                NaN                NaN                NaN
# 2      Netherlands                NaN                NaN                NaN
# 3           Sweden                NaN                NaN                NaN
# 4          Germany                NaN                NaN                NaN

# %%
nationality_names = df_player15_selected['nationality_name'].tolist()

# %%
for i in nationality_names:
  players = []
  players.append(i)
  for j in range(1, 4): # player1, 2, 3값만 가져오기 
    try:
      players.append(df_player15.loc[df_player15['rank_in_nation'] == j].loc[df_player15['nationality_name'] == i]['value_eur'].item())
      if j == 3:
        df_player15_edited.loc[df_player15_edited['nationality_name'] == i] = players
    except:
      continue

# %%
df_player15_edited.head()
# Out:
#   nationality_name  player1_value_eur  player2_value_eur  player3_value_eur
# 0        Argentina        100500000.0         45500000.0         45500000.0
# 1         Portugal         79000000.0         16500000.0         13500000.0
# 2      Netherlands         54500000.0         40500000.0         21000000.0
# 3           Sweden         52500000.0          9000000.0          7500000.0
# 4          Germany         63500000.0         44000000.0         40000000.0

# %% [markdown]
# Ranking Data

# %%
df_rankings = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/fifa/fifa_ranking.csv')

# %%
df_rankings = df_rankings.replace({"IR Iran":"Iran"})
df_rankings['weighted_points'] = df_rankings['cur_year_avg_weighted'] + df_rankings['two_year_ago_weighted'] + df_rankings['three_year_ago_weighted']
df_rankings['rank_date'] = pd.to_datetime(df_rankings['rank_date'])

# %%
df_rankings = df_rankings.query("rank_date >= '2015-01-01' and rank_date <= '2015-12-31'").reset_index(drop=True)
df_rankings.head()
# Out:
#    rank country_full country_abrv  total_points  previous_points  rank_change  \
# 0     1      Germany          GER       1725.29             1725            0
# 1     2    Argentina          ARG       1538.29             1538            0
# 2     3     Colombia          COL       1449.77             1450            0
# 3     4      Belgium          BEL       1417.27             1417            0
# 4     5  Netherlands          NED       1374.24             1374            0
#
#    cur_year_avg  cur_year_avg_weighted  last_year_avg  last_year_avg_weighted  \
# 0       1090.54                1090.54         566.83                  283.42
# 1        937.59                 937.59         590.90                  295.45
# 2        805.97                 805.97         632.31                  316.15
# 3        849.03                 849.03         652.93                  326.46
# 4        884.29                 884.29         527.71                  263.86
#
#    two_year_ago_avg  two_year_ago_weighted  three_year_ago_avg  \
# 0            765.86                 229.76              607.88
# 1            733.76                 220.13              425.62
# 2            794.27                 238.28              446.83
# 3            542.17                 162.65              395.59
# 4            428.54                 128.56              487.68
#
#    three_year_ago_weighted confederation  rank_date  weighted_points
# 0                   121.58          UEFA 2015-01-08          1441.88
# 1                    85.12      CONMEBOL 2015-01-08          1242.84
# 2                    89.37      CONMEBOL 2015-01-08          1133.62
# 3                    79.12          UEFA 2015-01-08          1090.80
# 4                    97.54          UEFA 2015-01-08          1110.39

# %%
df_rankings = df_rankings.rename(columns = {"country_full":"nationality_name"})

# %%
new_df = pd.merge(df_rankings, df_player15_edited, how='right',on='nationality_name')
new_df.head()
# Out:
#    rank nationality_name country_abrv  total_points  previous_points  \
# 0   2.0        Argentina          ARG       1538.29           1538.0
# 1   2.0        Argentina          ARG       1534.20           1538.0
# 2   2.0        Argentina          ARG       1577.19           1534.0
# 3   2.0        Argentina          ARG       1490.04           1577.0
# 4   2.0        Argentina          ARG       1493.70           1490.0
#
#    rank_change  cur_year_avg  cur_year_avg_weighted  last_year_avg  \
# 0          0.0        937.59                 937.59         590.90
# 1          0.0        937.59                 937.59         595.26
# 2          0.0        992.63                 992.63         559.57
# 3          0.0        919.87                 919.87         512.98
# 4          0.0        919.87                 919.87         512.98
#
#    last_year_avg_weighted  two_year_ago_avg  two_year_ago_weighted  \
# 0                  295.45            733.76                 220.13
# 1                  297.63            717.86                 215.36
# 2                  279.79            732.94                 219.88
# 3                  256.49            742.10                 222.63
# 4                  256.49            742.10                 222.63
#
#    three_year_ago_avg  three_year_ago_weighted confederation  rank_date  \
# 0              425.62                    85.12      CONMEBOL 2015-01-08
# 1              418.10                    83.62      CONMEBOL 2015-02-12
# 2              424.48                    84.90      CONMEBOL 2015-03-12
# 3              455.26                    91.05      CONMEBOL 2015-04-09
# 4              473.57                    94.71      CONMEBOL 2015-05-07
#
#    weighted_points  player1_value_eur  player2_value_eur  player3_value_eur
# 0          1242.84        100500000.0         45500000.0         45500000.0
# 1          1236.57        100500000.0         45500000.0         45500000.0
# 2          1297.41        100500000.0         45500000.0         45500000.0
# 3          1233.55        100500000.0         45500000.0         45500000.0
# 4          1237.21        100500000.0         45500000.0         45500000.0

# %%
new_df = pd.DataFrame(new_df, columns=['total_points','player1_value_eur', 'player2_value_eur', 'player3_value_eur'])

# %% [markdown]
# Heatmap 만들기 - player의 value_eur 와 ranking의 total_points 간의 correlation

# %%
fig, ax = plt.subplots()
fig.set_size_inches(10, 10)
corr1 = new_df.corr()
sns.heatmap(corr1, annot=True)

# %% [markdown]
# Heatmap 2 - player wage와 ranking의 correlation

# %%
df_player15_wage.head()
# Out:
#           short_name nationality_name  nationality_id  wage_eur  \
# 0           L. Messi        Argentina              52  550000.0
# 1  Cristiano Ronaldo         Portugal              38  375000.0
# 2          A. Robben      Netherlands              34  275000.0
# 3     Z. Ibrahimović           Sweden              46  275000.0
# 4           M. Neuer          Germany              21  300000.0
#
#    rank_in_nation
# 0               1
# 1               1
# 2               1
# 3               1
# 4               1

# %%
df_player15_edited_2 = pd.DataFrame(df_player15_wage, columns=['nationality_name', 'player1_wage_eur']) # 'player1_wage_eur'

for i in range(2,4):
    col = 'player' + str(i) + '_wage_eur'
    df_player15_edited_2[col] = np.nan

df_player15_edited_2.head()
# Out:
#   nationality_name  player1_wage_eur  player2_wage_eur  player3_wage_eur
# 0        Argentina               NaN               NaN               NaN
# 1         Portugal               NaN               NaN               NaN
# 2      Netherlands               NaN               NaN               NaN
# 3           Sweden               NaN               NaN               NaN
# 4          Germany               NaN               NaN               NaN

# %%
for i in nationality_names:
  players = []
  players.append(i)
  for j in range(1, 4): # player1, 2, 3값만 가져오기 
    try:
      players.append(df_player15_wage.loc[df_player15_wage['rank_in_nation'] == j].loc[df_player15_wage['nationality_name'] == i]['wage_eur'].item())
      if j == 3:
        df_player15_edited_2.loc[df_player15_edited_2['nationality_name'] == i] = players
    except:
      continue

# %%
new_df2 = pd.merge(df_rankings, df_player15_edited_2, how='right',on='nationality_name')
new_df2.tail()
# Out:
#         rank nationality_name country_abrv  total_points  previous_points  \
# 189521   8.0          England          ENG       1156.83           1157.0
# 189522  10.0          England          ENG       1142.82           1157.0
# 189523  10.0          England          ENG       1160.67           1143.0
# 189524   9.0          England          ENG       1179.13           1161.0
# 189525   9.0          England          ENG       1105.71           1179.0
#
#         rank_change  cur_year_avg  cur_year_avg_weighted  last_year_avg  \
# 189521          1.0        705.38                 705.38         411.37
# 189522         -2.0        705.38                 705.38         408.40
# 189523          0.0        692.90                 692.90         473.57
# 189524          1.0        713.69                 713.69         392.41
# 189525          0.0        595.78                 595.78         523.32
#
#         last_year_avg_weighted  two_year_ago_avg  two_year_ago_weighted  \
# 189521                  205.69            350.91                 105.27
# 189522                  204.20            338.91                 101.67
# 189523                  236.79            353.68                 106.10
# 189524                  196.20            496.41                 148.92
# 189525                  261.66            455.04                 136.51
#
#         three_year_ago_avg  three_year_ago_weighted confederation  rank_date  \
# 189521              702.50                   140.50          UEFA 2015-08-06
# 189522              657.88                   131.58          UEFA 2015-09-03
# 189523              624.38                   124.88          UEFA 2015-10-01
# 189524              601.57                   120.31          UEFA 2015-11-05
# 189525              558.77                   111.75          UEFA 2015-12-03
#
#         weighted_points  player1_wage_eur  player2_wage_eur  player3_wage_eur
# 189521           951.15          230000.0          150000.0          120000.0
# 189522           938.63          230000.0          150000.0          120000.0
# 189523           923.88          230000.0          150000.0          120000.0
# 189524           982.92          230000.0          150000.0          120000.0
# 189525           844.04          230000.0          150000.0          120000.0

# %%
new_df2 = pd.DataFrame(new_df2, columns=['total_points','player1_wage_eur', 'player2_wage_eur', 'player3_wage_eur'])

# %%
fig, ax = plt.subplots()
fig.set_size_inches(10, 10)
corr2 = new_df.corr()
sns.heatmap(corr2, annot=True)

# %% [markdown]
# 희민님 원래 코드

# %%
df_player15.loc[df_player15['rank_in_nation']==1].loc[df_player15['nationality_id'] == 52]['value_eur'].iloc[0]
# Out:
# 100500000.0

# %%
player = [52,]
for j in range(1, 12):
    player.append(df_player15.loc[df_player15['rank_in_nation'] == j].loc[df_player15['nationality_id'] == 52]['value_eur'].item())
    player.append(df_player15.loc[df_player15['rank_in_nation']==j].loc[df_player15['nationality_id']== 52]['wage_eur'].item())
    df_player15_edited.loc[len(df_player15_edited.index)] = player
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-28-206e4c0cb545> in <module>
#       3     player.append(df_player15.loc[df_player15['rank_in_nation'] == j].loc[df_player15['nationality_id'] == 52]['value_eur'].item())
#       4     player.append(df_player15.loc[df_player15['rank_in_nation']==j].loc[df_player15['nationality_id']== 52]['wage_eur'].item())
# ----> 5     df_player15_edited.loc[len(df_player15_edited.index)] = player
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexing.py in __setitem__(self, key, value)
#     721
#     722         iloc = self if self.name == "iloc" else self.obj.iloc
# --> 723         iloc._setitem_with_indexer(indexer, value, self.name)
#     724
#     725     def _validate_key(self, key, axis: int):
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexing.py in _setitem_with_indexer(self, indexer, value, name)
#    1722
#    1723             if missing:
# -> 1724                 self._setitem_with_indexer_missing(indexer, value)
#    1725                 return
#    1726
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexing.py in _setitem_with_indexer_missing(self, indexer, value)
#    2025                     # must have conforming columns
#    2026                     if len(value) != len(self.obj.columns):
# -> 2027                         raise ValueError("cannot set a row with mismatched columns")
#    2028
#    2029                 value = Series(value, index=self.obj.columns, name=indexer)
#
# ValueError: cannot set a row with mismatched columns

# %%
df_player15.loc[df_player15['rank_in_nation'] == 2].loc[df_player15['nationality_id'] == 52]['value_eur']

# %%
# home_score away_score home_player1_wage home_player2_wage home_player3_wage ... home_player11_wage away_player1_wage ... away_player11_wage
